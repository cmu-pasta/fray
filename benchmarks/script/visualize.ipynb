# %%
# %load_ext autoreload
# %autoreload 2

from configs import *
from visualize import *

# %%
for bm in BENCHMARKS:
    visualize_report(os.path.join(BASE, f"benchmarks/build/{bm}-report/schedule_simplified_0.csv"), bm)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 for bm in BENCHMARKS:
# ----> 2     visualize_report(os.path.join(BASE, f"benchmarks/build/{bm}-report/schedule_simplified_0.csv"), bm)
#
# File ~/repos/sfuzz/benchmarks/script/visualize.py:6, in visualize_report(path, name)
#       5 def visualize_report(path: str, name: str):
# ----> 6     df = pandas.read_csv(path, header=0)
#       7     df['operation'] = df['operation'].apply(lambda x: x.split('.')[-1])
#       8     sns.countplot(data=df, y='operation')
#
# ...
